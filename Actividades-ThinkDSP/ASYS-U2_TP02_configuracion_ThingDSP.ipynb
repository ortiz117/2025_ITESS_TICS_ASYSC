# %% [markdown]
# ## ITESS_TICS_ASYSC
# ## AGOSTO-DICIEMBRE
# ## DOCENTE: FRANCISCO JAVIER MONTECILLO PUENTES
# ## TEMA 2 SEÑALES PERIODICAS: SERIES DE FOURIER
# ## DESCRIPCION APROXIMACION DE UNA ONDA CUADRADA APROXIMACION DE SEÑALES PERIODICAS USANDO SERIES DE FOURIER
# $$ s(t) = a_0 + \sum_{n=1}^{\infty} [ a_n cos(2 \pi f n t ) + b_n sin(2 \pi f n t ) ]  $$
#
# $$
# s(f) = a_0 + \sum_{n=1}^{\infty} \left[ a_n \cos(2\pi f_n t) + b_n \sin(2\pi f_n t) \right]
# $$
#
# ## donde los coeficientes están dados por:
#
# $$
# a_0 = \frac{1}{T} \int_{0}^{T} f(t)\, dt
# $$
#
# $$
# a_n = \frac{2}{T} \int_{0}^{T} f(t)\cos(2\pi f_n t)\, dt
# $$
#
# $$
# b_n = \frac{2}{T} \int_{0}^{T} f(t)\sin(2\pi f_n t)\, dt
# $$
#
# ## PROGRAMADOR: ISAAC ORTIZ ARIAS
# ## 16 OCTUBRE 2025
#
# This notebook contains code examples form Chapter 1: Sounds and Singals

# %%
from thinkdsp import CosSignal, SinSignal

f = 0.25
k = 1
st = CosSignal(freq=f, amp=2*k/3.1416, offset=0)

# %%
from thinkdsp import decorate
wave = st.make_wave(duration=4)
wave.ys += 0.5

wave.plot()
decorate(xlabel='Time (s)')
import matplotlib.pyplot as plt
plt.grid(True, which= 'both')

# %%
from thinkdsp import decorate
wave = st.make_wave(duration=4)
wave.ys += 0.5

st.plot()
decorate(xlabel='Time (s)')
import matplotlib.pyplot as plt
plt.grid(True, which= 'both')

# %%
from thinkdsp import CosSignal, SinSignal

f = 0.25
k = 1
st2 = st + CosSignal(freq=f*3, amp=-3*k/3*3.1416, offset=0)

# %%
from thinkdsp import decorate
wave = st.make_wave(duration=14)
wave.ys += 0.5

st2.plot()
decorate(xlabel='Time (s)')
import matplotlib.pyplot as plt
plt.grid(True, which= 'both')

# %%
from thinkdsp import CosSignal, SinSignal

f = 0.25
k = 1
st3 = st2 + CosSignal(freq=f*5, amp=2*k/5*3.1416, offset=0)

# %%
from thinkdsp import decorate
wave = st.make_wave(duration=14)
wave.ys += 0.5

st3.plot()
decorate(xlabel='Time (s)')
import matplotlib.pyplot as plt
plt.grid(True, which= 'both')

# %%
from thinkdsp import decorate
wave = st.make_wave(duration=4)
wave.ys += 0.5
wave2 = st2.make_wave(duration=4)
wave2.ys += 0.5
wave3 = st.make_wave(duration=4)
wave3.ys += 0.5
st.plot()
st2.plot()
st3.plot()
decorate(xlabel='Time (s)')
import matplotlib.pyplot as plt
plt.grid(True, which= 'both')
